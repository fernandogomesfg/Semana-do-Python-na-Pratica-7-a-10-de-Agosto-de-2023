# %% [markdown]
# # Análises Preditivas

# %% [markdown]
# ## Bibliotecas

# %%
# !pip install prophet
# Out:
# ...
#      ---------------------------------------- 12.9/12.9 MB 5.8 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 83.2/83.2 kB 2.3 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 47.9/47.9 kB 2.5 MB/s eta 0:00:00
# ...
#      -------------------------------------- 736.9/736.9 kB 5.8 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 5.8/5.8 MB 6.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ---------------------------------------- 1.4/1.4 MB 9.0 MB/s eta 0:00:00
# ...
#   Created wheel for pymeeus: filename=PyMeeus-0.5.12-py3-none-any.whl size=732051 sha256=bdb4e901b5190a75f7d6e9e92f59077308ed4868aa6b92d08600b810a6ab376b
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\74\47\c4\678b0a3d5213e2f8500f3ea0f8dc3c81478e5b806c557dff58
# Successfully built pymeeus
# ...

# %%
import yfinance as yf
from prophet import Prophet
from prophet.plot import plot_plotly

# %% [markdown]
# ## Colectando dados

# %%
ticker = input("Digite o codigo da acao: ") # PETR4.SA
dados = yf.Ticker(ticker).history("2y")
# Out:
# Digite o codigo da acao: AAPL

# %%
dados
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2021-08-11 00:00:00-04:00  144.574619  145.237849  144.059867  144.386536
# 2021-08-12 00:00:00-04:00  144.713203  147.544313  144.366733  147.385925
# 2021-08-13 00:00:00-04:00  147.465104  147.930357  146.772179  147.593796
# 2021-08-16 00:00:00-04:00  147.039475  149.662714  144.990394  149.593414
# 2021-08-17 00:00:00-04:00  148.712380  150.147729  147.583897  148.672791
# ...                               ...         ...         ...         ...
# 2023-08-04 00:00:00-04:00  185.520004  187.380005  181.919998  181.990005
# 2023-08-07 00:00:00-04:00  182.130005  183.130005  177.350006  178.850006
# 2023-08-08 00:00:00-04:00  179.690002  180.270004  177.580002  179.800003
# 2023-08-09 00:00:00-04:00  180.869995  180.929993  177.009995  178.190002
# 2023-08-10 00:00:00-04:00  179.479996  180.750000  177.600006  177.970001
#
#                               Volume  Dividends  Stock Splits
# Date
# ...

# %% [markdown]
# ## Tratamento de dados

# %%
# Resentado o indice da tabela
treinamento = dados.reset_index()
treinamento = treinamento[["Date", "Close"]]
treinamento["Date"] = treinamento["Date"].dt.date
treinamento["Date"]
treinamento.columns = ["ds", "y"]
treinamento
# Out:
#              ds           y
# 0    2021-08-11  144.386536
# 1    2021-08-12  147.385925
# 2    2021-08-13  147.593796
# 3    2021-08-16  149.593414
# 4    2021-08-17  148.672791
# ..          ...         ...
# 498  2023-08-04  181.990005
# 499  2023-08-07  178.850006
# 500  2023-08-08  179.800003
# 501  2023-08-09  178.190002
# 502  2023-08-10  177.970001
#
# [503 rows x 2 columns]

# %% [markdown]
# ## Criando e Treinando o nosso modelo

# %%
# Carregando o modelo de dados
modelo = Prophet()

# %%
# Treinando o modelo
modelo.fit(treinamento)
# Out:
# 09:47:01 - cmdstanpy - INFO - Chain [1] start processing
# 09:47:01 - cmdstanpy - INFO - Chain [1] done processing

# %%
# criar o periodo de previsoes
periodo = modelo.make_future_dataframe(90)
periodo
# Out:
#             ds
# 0   2021-08-11
# 1   2021-08-12
# 2   2021-08-13
# 3   2021-08-16
# 4   2021-08-17
# ..         ...
# 588 2023-11-04
# 589 2023-11-05
# 590 2023-11-06
# 591 2023-11-07
# 592 2023-11-08
#
# [593 rows x 1 columns]

# %%
previsoes = modelo.predict(periodo)
previsoes
# Out:
#             ds       trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 0   2021-08-11  142.445500  134.082400  150.402603   142.445500   142.445500
# 1   2021-08-12  142.565675  133.358997  150.542935   142.565675   142.565675
# 2   2021-08-13  142.685851  133.026963  151.091856   142.685851   142.685851
# 3   2021-08-16  143.046377  134.386786  151.604945   143.046377   143.046377
# 4   2021-08-17  143.166552  134.328979  151.042812   143.166552   143.166552
# ..         ...         ...         ...         ...          ...          ...
# 588 2023-11-04  220.803352  207.355336  234.433157   211.892825   230.336422
# 589 2023-11-05  221.081918  208.226599  234.797302   211.932052   230.728317
# 590 2023-11-06  221.360483  208.947724  234.737038   212.078503   231.211323
# 591 2023-11-07  221.639049  208.756777  235.824463   212.243098   231.734825
# 592 2023-11-08  221.917614  208.218314  235.755918   212.356209   232.137099
#
# ...

# %% [markdown]
# ## Visualização das previsões

# %%
plot_plotly(modelo, previsoes)
# Out:
# <div>                            <div id="a57022ed-02e9-4c0c-beaa-8e12455d98ee" class="plotly-graph-div" style="height:600px; width:900px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a57022ed-02e9-4c0c-beaa-8e12455d98ee")) {                    Plotly.newPlot(                        "a57022ed-02e9-4c0c-beaa-8e12455d98ee",                        [{"marker":{"color":"black","size":4},"mode":"markers","name":"Actual","x":["2021-08-11T00:00:00","2021-08-12T00:00:00","2021-08-13T00:00:00","2021-08-16T00:00:00","2021-08-17T00:00:00","2021-08-18T00:00:00","2021-08-19T00:00:00","2021-08-20T00:00:00","2021-08-23T00:00:00","2021-08-24T00:00:00","2021-08-25T00:00:00","2021-08-26T00:00:00","2021-08-27T00:00:00","2021-08-30T00:00:00","2021-08-31T00:00:00","2021-09-01T00:00:00","2021-09-02T00:00:00","2021-09-03T00:00
# ...

# %%
import yfinance as yf
from prophet import Prophet
from prophet.plot import plot_plotly

# %%
# Colectando dados
ticker = input("Digite o codigo da acao: ") # PETR4.SA
dados = yf.Ticker(ticker).history("2y")

# Tratamento de dados
# Resentado o indice da tabela
treinamento = dados.reset_index()
treinamento = treinamento[["Date", "Close"]]
treinamento["Date"] = treinamento["Date"].dt.date
treinamento["Date"]
treinamento.columns = ["ds", "y"]

# Criando e Treinando o nosso modelo
# Carregando o modelo de dados
modelo = Prophet()

# Treinando o modelo
modelo.fit(treinamento)

# criar o periodo de previsoes
periodo = modelo.make_future_dataframe(90)

previsoes = modelo.predict(periodo)
previsoes

# Visualização das previsões
plot_plotly(modelo, previsoes)
# Out:
# Digite o codigo da acao: BBAS3.SA
# 10:11:50 - cmdstanpy - INFO - Chain [1] start processing
# 10:11:51 - cmdstanpy - INFO - Chain [1] done processing
# ...
